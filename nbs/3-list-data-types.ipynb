# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint,params={'duration':'1 minute','pages':['/about','/contact']})
print('ok', response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# ok True
# [{'avg_duration': 2526.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 1,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 1636.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 2,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 3086.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 2,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 3957.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 1,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2959.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 3,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 4865.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 1,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2155.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 1,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2563.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 1,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2839.1666666666665,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 6,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2798.0,
#   'bucket': '2025-07-24T05:05:00Z',
#   'count': 2,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2681.9444444444443,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 18,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2060.76,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 25,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2575.8372093023254,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 43,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2415.0363636363636,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 55,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2271.6530612244896,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 49,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2641.9607843137255,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 51,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2666.5714285714284,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 7,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2857.4615384615386,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 13,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2683.463768115942,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 69,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2493.557142857143,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 70,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2686.375,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 24,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2561.8,
#   'bucket': '2025-07-24T05:06:00Z',
#   'count': 25,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2918.818181818182,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 11,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2989.0,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 21,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2396.1951219512193,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 41,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2901.8444444444444,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 45,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2731.6071428571427,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 28,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2417.740740740741,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 27,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2982.909090909091,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 11,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2601.1,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 10,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2146.0,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 49,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2343.603448275862,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 58,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2486.16,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 25,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2978.6666666666665,
#   'bucket': '2025-07-24T05:07:00Z',
#   'count': 15,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2002.3529411764705,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 17,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2892.3333333333335,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 12,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2699.2368421052633,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 38,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2840.925,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 40,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2064.3214285714284,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 28,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2381.9166666666665,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 36,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 1832.2,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 10,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2092.2,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 5,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 1912.3157894736842,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 57,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2507.89552238806,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 67,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2187.5833333333335,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 24,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2659.68,
#   'bucket': '2025-07-24T05:08:00Z',
#   'count': 25,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 1876.25,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 4,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 3380.5,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 8,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 1876.0,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 10,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 3471.6666666666665,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 9,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2887.9333333333334,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 15,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 1477.5,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 2,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 977.0,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 1,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2215.9411764705883,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 17,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 1839.3684210526317,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 19,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2304.8571428571427,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 7,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2272.625,
#   'bucket': '2025-07-24T05:09:00Z',
#   'count': 8,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 1698.6153846153845,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 13,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 1519.4,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 5,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2842.3,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 20,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 3274.764705882353,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 17,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 3369.2,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 15,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2488.3529411764707,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 17,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2605.5,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 2,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2303.285714285714,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 7,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2460.5416666666665,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 24,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2695.45,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 40,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2156.4166666666665,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 12,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2576.3,
#   'bucket': '2025-07-24T05:10:00Z',
#   'count': 10,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2509.4545454545455,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 11,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2612.785714285714,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 14,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2732.0476190476193,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 21,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2437.8260869565215,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 23,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2515.95,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 20,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2021.48,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 25,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 3853.75,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 4,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2177.0,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 5,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2502.2285714285713,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 35,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2408.875,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 40,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2170.1875,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 16,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2558.8888888888887,
#   'bucket': '2025-07-24T05:11:00Z',
#   'count': 9,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 3513.4285714285716,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 7,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2212.5454545454545,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 11,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2474.027777777778,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 36,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2630.4666666666667,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 30,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 1882.516129032258,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 31,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2580.8947368421054,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 19,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2343.6,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 10,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 4152.0,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 3,
#   'operating_system': 'Other',
#   'ua': ''},
#  {'avg_duration': 2271.1372549019607,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 51,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2485.92,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 50,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 1809.0,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 22,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 1968.8,
#   'bucket': '2025-07-24T05:12:00Z',
#   'count': 20,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 2035.0,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 2,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2710.0,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 1,
#   'operating_system': 'Android',
#   'ua': ''},
#  {'avg_duration': 2834.5555555555557,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 9,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 2334.9166666666665,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 12,
#   'operating_system': 'Linux',
#   'ua': ''},
#  {'avg_duration': 3000.0,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 3,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 1771.2,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 5,
#   'operating_system': 'MacOS',
#   'ua': ''},
#  {'avg_duration': 2056.777777777778,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 9,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 2327.5,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 6,
#   'operating_system': 'Windows',
#   'ua': ''},
#  {'avg_duration': 3456.0,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 5,
#   'operating_system': 'iOS',
#   'ua': ''},
#  {'avg_duration': 4057.6666666666665,
#   'bucket': '2025-07-24T05:13:00Z',
#   'count': 3,
#   'operating_system': 'iOS',
#   'ua': ''}]

# %%
detail_path = "/api/events/13"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print('ok', r.status_code)
if r.ok:
    data = r.json()
    pprint(data)
# Out:
# ok 404
